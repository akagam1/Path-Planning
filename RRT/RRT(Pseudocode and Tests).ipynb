# %% [markdown]
# # Rapidly Expanding Random Trees (RRT) Algorithm
#
# ## pseudocode:
#
#
# ```
# def RRT(START, GOAL):
#     TREE = []
#     TREE.add(START)
#     DELTA = maximum distance between sampled node and nearest node.
#     REPEAT n times:
#         X = generateNewConfiguration()
#         if X in FREE_SPACE:
#             for nodes in TREE:
#                 Y = argmin(nodes, criteria=distance)
#             if DIST(X, Y) < DELTA:
#                 Find a configuration Z that is at DELTA distance along the path from X to Y
#                 if TRAVERSABLE(X, Z):
#                     X.parent = Y
#                     TREE.add(X)
#             else:
#                 if TRAVERSABLE(X, Y):
#                     X.parent = Y
#                     TREE.add(X)
#             if X is GOAL:
#                 report "SUCCESS"
#                 break

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
import random
import numpy as np
import time

# %%
fig, ax = plt.subplots()
x, y = [],[]
sc = ax.scatter(x,y)
plt.xlim(0,10)
plt.ylim(0,10)

plt.ion()
plt.draw()
for i in range(10):
    x.append(np.random.rand(1)*10)
    y.append(np.random.rand(1)*10)
    sc.set_offsets(np.c_[x,y])
    fig.canvas.draw_idle()
    plt.pause(0.1)
# Out:
# <img src="data:image/png;base64,..." width="863.5">
